# %%
# --- LA LÓGICA PURA (Micro-Laberinto) ---
# Objetivo: Llevar tu posición (x, y) a la meta (2, 2)
# No hay paredes, solo matemáticas.

x, y = 0, 0  # Empiezas en el origen

# Mientras NO estemos en la coordenada (2, 2)...
while (x, y) != (2, 2):
    print(f" Estás en: ({x}, {y}) | 🏁 Meta: (2, 2)")
    m = input("Mueve (d=derecha, s=abajo): ")
    
    if m == "d": x = x + 1  # Derecha es sumar en X
    if m == "s": y = y + 1  # Abajo es sumar en Y

print("¡Llegaste a la meta!")
# Out:
# 📍 Estás en: (0, 0) | 🏁 Meta: (2, 2)
# 📍 Estás en: (0, 1) | 🏁 Meta: (2, 2)
# 📍 Estás en: (1, 1) | 🏁 Meta: (2, 2)
# 📍 Estás en: (1, 2) | 🏁 Meta: (2, 2)
# 🎉 ¡Llegaste a la meta!
